# %%
from os.path import split
s = input("Enter 3 real number (separated by space): ")
s = s.split()
a = float(s[0])
b = float(s[1])
c = float(s[2])
print(f"a = {a}, b = {b}, c = {c}")
if a == 0:
  print("Khong phai phuong trinh bac 2.")
else:
  delta = b * b - 4*a*c
if delta > 0:
  print("phuong trinh co 2 nghiem phan biet")
elif delta == 0:
  print("phuong trinh co nghiem kep")
elif delta < 0:
  print("phuong trinh vo nghiem")
else:
  x1 = (-b + math.sprt(delta)) / (2*a)
  x1 = (-b - math.sprt(delta)) / (2*a)
  print("x1 =",x1)
  print("x2 =",x2)
# Out:
# Enter 3 real number (separated by space): 1 2 1
# a = 1.0, b = 2.0, c = 1.0
# phuong trinh co nghiem kep
